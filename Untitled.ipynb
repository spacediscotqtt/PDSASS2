# %%
# Import pandas library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import scipy
import seaborn as sns
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.read_csv('sobar-72.csv')

# %%
df.head()
# Out:
#    behavior_sexualRisk  behavior_eating  behavior_personalHygine  \
# 0                   10               13                       12
# 1                   10               11                       11
# 2                   10               15                        3
# 3                   10               11                       10
# 4                    8               11                        7
#
#    intention_aggregation  intention_commitment  attitude_consistency  \
# 0                      4                     7                     9
# 1                     10                    14                     7
# 2                      2                    14                     8
# 3                     10                    15                     7
# 4                      8                    10                     7
#
#    attitude_spontaneity  norm_significantPerson  norm_fulfillment  \
# 0                    10                       1                 8
# ...

# %%
df.shape
# Out:
# (72, 20)

# %%
print(df.dtypes)
print(df.dtypes.value_counts())
# Out:
# behavior_sexualRisk           int64
# behavior_eating               int64
# behavior_personalHygine       int64
# intention_aggregation         int64
# intention_commitment          int64
# attitude_consistency          int64
# attitude_spontaneity          int64
# norm_significantPerson        int64
# norm_fulfillment              int64
# perception_vulnerability      int64
# perception_severity           int64
# motivation_strength           int64
# motivation_willingness        int64
# socialSupport_emotionality    int64
# socialSupport_appreciation    int64
# socialSupport_instrumental    int64
# empowerment_knowledge         int64
# empowerment_abilities         int64
# empowerment_desires           int64
# ca_cervix                     int64
# dtype: object
# int64    20
# dtype: int64

# %%
df.isnull().any()
# Out:
# behavior_sexualRisk           False
# behavior_eating               False
# behavior_personalHygine       False
# intention_aggregation         False
# intention_commitment          False
# attitude_consistency          False
# attitude_spontaneity          False
# norm_significantPerson        False
# norm_fulfillment              False
# perception_vulnerability      False
# perception_severity           False
# motivation_strength           False
# motivation_willingness        False
# socialSupport_emotionality    False
# socialSupport_appreciation    False
# socialSupport_instrumental    False
# empowerment_knowledge         False
# empowerment_abilities         False
# empowerment_desires           False
# ca_cervix                     False
# dtype: bool

# %%
df.columns
# Out:
# Index(['behavior_sexualRisk', 'behavior_eating', 'behavior_personalHygine',
#        'intention_aggregation', 'intention_commitment', 'attitude_consistency',
#        'attitude_spontaneity', 'norm_significantPerson', 'norm_fulfillment',
#        'perception_vulnerability', 'perception_severity',
#        'motivation_strength', 'motivation_willingness',
#        'socialSupport_emotionality', 'socialSupport_appreciation',
#        'socialSupport_instrumental', 'empowerment_knowledge',
#        'empowerment_abilities', 'empowerment_desires', 'ca_cervix'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                             count       mean       std  min    25%   50%  \
# behavior_sexualRisk          72.0   9.666667  1.186782  2.0  10.00  10.0
# behavior_eating              72.0  12.791667  2.361293  3.0  11.00  13.0
# behavior_personalHygine      72.0  11.083333  3.033847  3.0   9.00  11.0
# intention_aggregation        72.0   7.902778  2.738148  2.0   6.00  10.0
# intention_commitment         72.0  13.347222  2.374511  6.0  11.00  15.0
# attitude_consistency         72.0   7.180556  1.522844  2.0   6.00   7.0
# attitude_spontaneity         72.0   8.611111  1.515698  4.0   8.00   9.0
# norm_significantPerson       72.0   3.125000  1.845722  1.0   1.00   3.0
# norm_fulfillment             72.0   8.486111  4.907577  3.0   3.00   7.0
# perception_vulnerability     72.0   8.513889  4.275686  3.0   5.00   8.0
# perception_severity          72.0   5.388889  3.400727  2.0   2.00   4.0
# motivation_strength          72.0  12.652778  3.207209  3.0  11.00  14.0
# ...

# %%
hasCancer = df[df['ca_cervix'] == 1]

# %%
noCancer = df[df['ca_cervix'] == 0]

# %%
df['ca_cervix'].value_counts().plot(kind='pie', autopct='%1.1f%%',figsize=(7,7), fontsize=14)
plt.show()

# %%
df.pivot(columns='ca_cervix').behavior_sexualRisk.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('1. Willingness against sexual intercourse despite HPV risk', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df['behavior_sexualRisk'].mean()
# Out:
# 9.666666666666666

# %%
df.pivot(columns='ca_cervix').behavior_eating.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('2. rating based on nutritious diet ', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df['behavior_eating'].mean()
# Out:
# 12.791666666666666

# %%
df.pivot(columns='ca_cervix').behavior_personalHygine.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('3. rating based on personalhygiene ', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df['behavior_eating'].median()
# Out:
# 13.0

# %%
df.pivot(columns='ca_cervix').intention_commitment.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('4. rating based on intention to commit', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df.pivot(columns='ca_cervix').attitude_consistency.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('5. rating based on consistency of attitude', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df.pivot(columns='ca_cervix').attitude_spontaneity.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('6. rating based on spontaneity of attitude', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df.pivot(columns='ca_cervix').perception_vulnerability.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('7. rating based on perception of vulnerability', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df.pivot(columns='ca_cervix').norm_fulfillment.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('8. rating based on fulfillment of norms', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df.pivot(columns='ca_cervix').empowerment_knowledge.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('9. rating based on knowledge for prevention', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
df.pivot(columns='ca_cervix').empowerment_desires.plot(kind = 'hist', stacked=True,figsize=(8,7),fontsize=13)
plt.title('10. rating based on desire to determine prevention', fontsize=15)
plt.xlabel('rating', fontsize=15)
plt.show()

# %%
v = df['ca_cervix'].unique()
m_1 = df['ca_cervix'] == v[0]
m_2 = df['ca_cervix'] == v[1]
df.loc[m_1, 'ca_cervix'] = 0
df.loc[m_2, 'ca_cervix'] = 1
df['ca_cervix'].value_counts()

colors_palette = {0: 'red', 1: 'blue'}

colors = [colors_palette[c] for c in df['ca_cervix']]

usedcolumn = ['behavior_sexualRisk','behavior_eating','behavior_personalHygine','intention_commitment','attitude_consistency','attitude_spontaneity','perception_vulnerability','norm_fulfillment','empowerment_knowledge','empowerment_desires']
pd.plotting.scatter_matrix(df[usedcolumn], s = 25, alpha = 0.5, figsize = (16, 16), c = colors, diagonal = 'hist', marker = 'o', grid = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.corr()
# Out:
#                             behavior_sexualRisk  behavior_eating  \
# behavior_sexualRisk                    1.000000        -0.165857
# behavior_eating                       -0.165857         1.000000
# behavior_personalHygine                0.003912         0.224623
# intention_aggregation                 -0.005779         0.116634
# intention_commitment                   0.126616         0.116075
# attitude_consistency                  -0.067541         0.124197
# attitude_spontaneity                  -0.057420         0.307610
# norm_significantPerson                 0.057869         0.038376
# norm_fulfillment                       0.158799        -0.048262
# perception_vulnerability               0.175791        -0.000407
# perception_severity                    0.067469        -0.077467
# motivation_strength                   -0.041937        -0.141732
# motivation_willingness                 0.309357        -0.077380
# ...

# %%
#* 2.2 exploring the relationship between: 
#1. personalhygiene/eating habits 
#2. attitude_consistency/ eating habits
#3. attitude_consistency/personal hygiene
#4. attitude_consistency/intention_commitment
#5. perception_vulnerability/intention_commitment
#6. empowerment_knowledge/behaviour eating
#7. empowerment_knowledge/preception_vulnerability
#8. empowerment_knowledge/empowerment_fulfilment
#9. empowerment_desire/empowerment_fulfilment
#10. empowerment_desire/empowerment_knowledge

# %%
withCc = df.loc[df['ca_cervix'] == 1]
withoutCc = df.loc[df['ca_cervix'] == 0]

# %%
x = withCc['behavior_personalHygine']
y = withCc['behavior_eating']
plt.scatter(x, y,alpha = 0.5, color = 'blue')

x = withoutCc['behavior_personalHygine']
y = withoutCc['behavior_eating']
plt.scatter(x, y,alpha = 0.5, color = 'red')
plt.title('11. hygiene behaviour rating combined with eating behaviour ', fontsize=15)
plt.show()
